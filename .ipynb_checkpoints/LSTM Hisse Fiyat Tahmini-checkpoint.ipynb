# %% [markdown]
# # OHLC Verilerinden hisse tahminlemesi

# %% [markdown]
# # Kütüphanelerin alınması

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import math
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM,Dense, Activation, Dropout
from keras.callbacks import ModelCheckpoint,EarlyStopping
import pandas_datareader.data as web
from dateutil.relativedelta import relativedelta
import datetime
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Genel fonksiyonlar

# %%
def veri_kaydirmaca(hisse_verisi, gun_sayisi): # Gün sayısı kadar uzat T+1...
    data_X, data_Y = [], []
    for i in range(len(hisse_verisi)-gun_sayisi-1):
        a = hisse_verisi[i:(i+gun_sayisi), 0]
        data_X.append(a)
        data_Y.append(hisse_verisi[i + gun_sayisi, 0])
    return np.array(data_X), np.array(data_Y)

# %%
def veri_al(hisse_kodu):
    baslangic = datetime.date.today() - relativedelta(years=yil)
    bitis = datetime.date.today()
    df = web.DataReader(hisse_kodu, "yahoo", baslangic, bitis).dropna()
    df.drop(['Volume'], 1, inplace=True)    
    df.drop(['Adj Close'], 1, inplace=True)        
    return df

# %% [markdown]
# # Parametreler

# %%
hisse_kodu = 'ISCTR.IS'
yil = 5
gun_sayisi = 1
ag_katman_yapisi = [128, 128, 32, 1]
d = 0.2
train=True
verbose=2
np.random.seed(13)

# %% [markdown]
# # Veri indirme

# %%
hisse_verisi = veri_al(hisse_kodu)

# %%
hisse_verisi_np = np.arange(1, len(hisse_verisi) + 1, 1)

# %%
def plot_stock(df):
    print(df.tail())
    plt.figure(figsize=(16, 7))
    plt.plot(df['Close'], color='red', label='Close')
    plt.legend(loc='best')
    plt.show()

# %%
plot_stock(hisse_verisi)
# Out:
#             High   Low  Open  Close
# Date
# 2019-01-02  4.51  4.28  4.51   4.30
# 2019-01-03  4.35  4.08  4.27   4.12
# 2019-01-04  4.25  4.14  4.16   4.23
# 2019-01-07  4.30  4.23  4.26   4.25
# 2019-01-09  4.24  4.21  4.23   4.23

# %%
kapanis_degeri = hisse_verisi[['Close']]

# %%
plt.figure(figsize=(16, 7))
plt.plot(hisse_verisi_np, kapanis_degeri, 'g', label = 'Kapanış')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# # Normalize

# %%
#kapanis_degeri = np.reshape(kapanis_degeri.values, (len(kapanis_degeri),1)) 
scaler = MinMaxScaler(feature_range=(0, 1))
kapanis_degeri = scaler.fit_transform(kapanis_degeri)

# %% [markdown]
# # Train - Test Split

# %%
train_kapanis = int(len(kapanis_degeri) * 0.75)
test_kapanis = len(kapanis_degeri) - train_kapanis
train_kapanis, test_kapanis = kapanis_degeri[0:train_kapanis,:], kapanis_degeri[train_kapanis:len(kapanis_degeri),:]

# %%
trainX, trainY = veri_kaydirmaca(train_kapanis, 1)
testX, testY = veri_kaydirmaca(test_kapanis, 1)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # LSTM Model

# %%
checkpointer = ModelCheckpoint(filepath="hisseKahin.h5",
                               monitor="val_loss", 
                               verbose=verbose, 
                               save_best_only=True , 
                               mode='auto')

eStop = EarlyStopping(monitor='val_loss', 
                      patience=50, 
                      verbose=verbose)

model = Sequential()

model.add(LSTM(ag_katman_yapisi[0], input_shape=(1, gun_sayisi), return_sequences=True))
model.add(Dropout(d))

model.add(LSTM(ag_katman_yapisi[1], input_shape=(1, gun_sayisi), return_sequences=False))
model.add(Dropout(d))

model.add(Dense(ag_katman_yapisi[2],kernel_initializer="uniform",activation='relu'))        
model.add(Dense(ag_katman_yapisi[3],kernel_initializer="uniform",activation='linear'))

model.compile(loss='mse',optimizer='adam')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 128)            66560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train'e başla

# %%
if train:
    train_sonuc = model.fit(trainX, trainY, 
                            epochs=33, 
                            batch_size=32, 
                            validation_data=(testX, testY),
                            verbose=verbose, callbacks=[eStop,checkpointer])
model.load_weights('hisseKahin.h5')
# Out:
# Train on 974 samples, validate on 324 samples
# Epoch 1/33
#  - 3s - loss: 0.1633 - val_loss: 0.1505
#
# Epoch 00001: val_loss improved from inf to 0.15053, saving model to hisseKahin.h5
# Epoch 2/33
#  - 0s - loss: 0.0397 - val_loss: 0.0471
#
# Epoch 00002: val_loss improved from 0.15053 to 0.04708, saving model to hisseKahin.h5
# Epoch 3/33
#  - 0s - loss: 0.0187 - val_loss: 0.0224
#
# Epoch 00003: val_loss improved from 0.04708 to 0.02237, saving model to hisseKahin.h5
# Epoch 4/33
#  - 0s - loss: 0.0088 - val_loss: 0.0077
#
# Epoch 00004: val_loss improved from 0.02237 to 0.00772, saving model to hisseKahin.h5
# Epoch 5/33
#  - 0s - loss: 0.0028 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00772 to 0.00192, saving model to hisseKahin.h5
# Epoch 6/33
#  - 0s - loss: 0.0016 - val_loss: 0.0015
#
# Epoch 00006: val_loss improved from 0.00192 to 0.00145, saving model to hisseKahin.h5
# Epoch 7/33
#  - 0s - loss: 0.0012 - val_loss: 0.0013
#
# Epoch 00007: val_loss improved from 0.00145 to 0.00132, saving model to hisseKahin.h5
# Epoch 8/33
#  - 0s - loss: 0.0012 - val_loss: 0.0013
#
# Epoch 00008: val_loss improved from 0.00132 to 0.00127, saving model to hisseKahin.h5
# Epoch 9/33
#  - 0s - loss: 0.0013 - val_loss: 0.0014
#
# Epoch 00009: val_loss did not improve from 0.00127
# Epoch 10/33
#  - 0s - loss: 0.0013 - val_loss: 0.0013
#
# Epoch 00010: val_loss did not improve from 0.00127
# Epoch 11/33
#  - 0s - loss: 0.0013 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00127 to 0.00122, saving model to hisseKahin.h5
# Epoch 12/33
#  - 0s - loss: 0.0013 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00122 to 0.00121, saving model to hisseKahin.h5
# Epoch 13/33
#  - 0s - loss: 0.0015 - val_loss: 0.0014
#
# Epoch 00013: val_loss did not improve from 0.00121
# Epoch 14/33
#  - 0s - loss: 0.0014 - val_loss: 0.0012
#
# Epoch 00014: val_loss did not improve from 0.00121
# Epoch 15/33
#  - 0s - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00121 to 0.00113, saving model to hisseKahin.h5
# Epoch 16/33
#  - 0s - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00016: val_loss did not improve from 0.00113
# Epoch 17/33
#  - 0s - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00113
# Epoch 18/33
#  - 0s - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00113
# Epoch 19/33
#  - 0s - loss: 0.0013 - val_loss: 0.0010
#
# Epoch 00019: val_loss improved from 0.00113 to 0.00103, saving model to hisseKahin.h5
# Epoch 20/33
#  - 0s - loss: 0.0012 - val_loss: 0.0012
#
# Epoch 00020: val_loss did not improve from 0.00103
# Epoch 21/33
#  - 0s - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00021: val_loss did not improve from 0.00103
# Epoch 22/33
#  - 0s - loss: 0.0011 - val_loss: 0.0010
#
# Epoch 00022: val_loss did not improve from 0.00103
# Epoch 23/33
#  - 0s - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00023: val_loss did not improve from 0.00103
# Epoch 24/33
#  - 0s - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00024: val_loss did not improve from 0.00103
# Epoch 25/33
#  - 0s - loss: 0.0011 - val_loss: 9.8823e-04
#
# Epoch 00025: val_loss improved from 0.00103 to 0.00099, saving model to hisseKahin.h5
# Epoch 26/33
#  - 0s - loss: 0.0010 - val_loss: 9.6549e-04
#
# Epoch 00026: val_loss improved from 0.00099 to 0.00097, saving model to hisseKahin.h5
# Epoch 27/33
#  - 0s - loss: 0.0010 - val_loss: 9.5958e-04
#
# Epoch 00027: val_loss improved from 0.00097 to 0.00096, saving model to hisseKahin.h5
# Epoch 28/33
#  - 0s - loss: 0.0010 - val_loss: 9.5702e-04
#
# Epoch 00028: val_loss improved from 0.00096 to 0.00096, saving model to hisseKahin.h5
# Epoch 29/33
#  - 0s - loss: 0.0011 - val_loss: 9.7664e-04
#
# Epoch 00029: val_loss did not improve from 0.00096
# Epoch 30/33
#  - 0s - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00030: val_loss did not improve from 0.00096
# Epoch 31/33
#  - 0s - loss: 9.5771e-04 - val_loss: 0.0011
#
# Epoch 00031: val_loss did not improve from 0.00096
# Epoch 32/33
#  - 0s - loss: 0.0011 - val_loss: 9.6803e-04
#
# Epoch 00032: val_loss did not improve from 0.00096
# Epoch 33/33
#  - 0s - loss: 0.0011 - val_loss: 0.0010
#
# Epoch 00033: val_loss did not improve from 0.00096

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# # Training set ve Test seti sonuçları

# %%
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train RMSE: %.2f' % (trainScore))
# Out:
# Train RMSE: 0.10

# %%
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test RMSE: %.2f' % (testScore))
# Out:
# Test RMSE: 0.14

# %%
plt.figure(figsize=(16, 7))
plt.plot(train_sonuc.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper right')
plt.show()

# %% [markdown]
# # Tahmin ve gerçek sonuçlar

# %%
trainPredictPlot = np.empty_like(kapanis_degeri)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[gun_sayisi:len(trainPredict)+gun_sayisi, :] = trainPredict

# %%
testPredictPlot = np.empty_like(kapanis_degeri)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(gun_sayisi*2)+1:len(kapanis_degeri)-1, :] = testPredict

# %%
kapanis_degeri = scaler.inverse_transform(kapanis_degeri)

# %%
plt.figure(figsize=(16, 7))
plt.plot(kapanis_degeri, 'g', label = 'gerçek')
plt.plot(trainPredictPlot, 'r', label = 'train')
plt.plot(testPredictPlot, 'b', label = 'test')
plt.legend(loc = 'upper right')
plt.xlabel('Günlük veri')
plt.ylabel('Fiyat')
plt.show()

# %% [markdown]
# # Yarınki fiyat

# %%
son_gun_fiyat = kapanis_degeri[-1]
son_gun_fiyat_scaled = scaler.fit_transform(np.reshape(son_gun_fiyat, (1,1)))
ertesi_gun_fiyat = model.predict(np.reshape(son_gun_fiyat_scaled, (1,1,1)))
son_gun_fiyat = np.asscalar(son_gun_fiyat)
ertesi_gun_fiyat = np.asscalar(scaler.inverse_transform(ertesi_gun_fiyat))

# %%
if ertesi_gun_fiyat > son_gun_fiyat: print("Al")
if ertesi_gun_fiyat < son_gun_fiyat: print("Sat")
if ertesi_gun_fiyat == son_gun_fiyat: print("Tut")
# Out:
# Al
